# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset and Knowledge settings

# %%
import pandas as pd

df = pd.read_csv('./resources/dry_bean/data.csv')
df['Area'] = df['Area'].astype(float)
df['ConvexArea'] = df['ConvexArea'].astype(float)
df['Class'] = df['Class'].astype(float)
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395.0    610.291         208.1781         173.8887        1.1972
# 1      28734.0    638.018         200.5248         182.7344        1.0974
# 2      29380.0    624.110         212.8261         175.9311        1.2097
# 3      30008.0    645.884         210.5580         182.5165        1.1536
# 4      30140.0    620.134         201.8479         190.2793        1.0608
# ...        ...        ...              ...              ...           ...
# 13606  42097.0    759.696         288.7216         185.9447        1.5527
# 13607  42101.0    757.499         281.5764         190.7131        1.4764
# 13608  42139.0    759.321         281.5399         191.1880        1.4726
# 13609  42147.0    763.779         283.3826         190.2757        1.4893
# 13610  42159.0    772.237         295.1427         182.2047        1.6198
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  roundness  \
# 0            0.5498     28715.0       190.1411  0.7639    0.9889     0.9580
# 1            0.4118     29172.0       191.2728  0.7840    0.9850     0.8870
# 2            0.5627     29690.0       193.4109  0.7781    0.9896     0.9478
# 3            0.4986     30724.0       195.4671  0.7827    0.9767     0.9039
# 4            0.3337     30417.0       195.8965  0.7731    0.9909     0.9849
# ...             ...         ...            ...     ...       ...        ...
# 13606        0.7650     42508.0       231.5158  0.7146    0.9903     0.9166
# 13607        0.7357     42494.0       231.5268  0.7999    0.9908     0.9220
# 13608        0.7341     42569.0       231.6313  0.7299    0.9899     0.9184
# 13609        0.7411     42667.0       231.6532  0.7054    0.9878     0.9079
# 13610        0.7867     42600.0       231.6862  0.7890    0.9896     0.8884
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0           0.9134        0.0073        0.0031        0.8342        0.9987
# 1           0.9539        0.0070        0.0036        0.9099        0.9984
# 2           0.9088        0.0072        0.0030        0.8259        0.9991
# 3           0.9283        0.0070        0.0032        0.8618        0.9942
# 4           0.9705        0.0067        0.0037        0.9419        0.9992
# ...            ...           ...           ...           ...           ...
# 13606       0.8019        0.0069        0.0017        0.6430        0.9984
# 13607       0.8223        0.0067        0.0019        0.6761        0.9982
# 13608       0.8227        0.0067        0.0019        0.6769        0.9968
# 13609       0.8175        0.0067        0.0019        0.6682        0.9952
# 13610       0.7850        0.0070        0.0016        0.6162        0.9982
#
#        Class
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
# ...      ...
# 13606    3.0
# 13607    3.0
# 13608    3.0
# 13609    3.0
# 13610    3.0
#
# [13611 rows x 17 columns]

# %%
display(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  float64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  float64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  float64
# dtypes: float64(17)
# memory usage: 1.8 MB
# None
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601200       122.512700
# 25%     36328.000000    703.523500       253.303600       175.848150
# 50%     44652.000000    794.941000       296.883400       192.431700
# 75%     61332.000000    977.213000       376.495000       217.031750
# max    254616.000000   1985.370000       738.860200       460.198500
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064219      0.749733
# std        0.246679      0.092001   29774.915817      59.177120      0.049086
# min        1.024900      0.219000   20684.000000     161.243800      0.555300
# 25%        1.432300      0.715900   36714.500000     215.068000      0.718600
# 50%        1.551100      0.764400   45178.000000     238.438000      0.759900
# 75%        1.707100      0.810500   62294.000000     279.446450      0.786900
# max        2.430300      0.911400  263261.000000     569.374400      0.866200
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987142      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000597
# min        0.919200      0.489600      0.640600      0.002800      0.000600
# 25%        0.985700      0.832100      0.762450      0.005900      0.001200
# 50%        0.988300      0.883200      0.801300      0.006600      0.001700
# 75%        0.990000      0.916900      0.834300      0.007300      0.002200
# max        0.994700      0.990700      0.987300      0.010500      0.003700
#
#        ShapeFactor3  ShapeFactor4         Class
# count  13611.000000  13611.000000  13611.000000
# mean       0.643590      0.995063      3.532657
# std        0.098996      0.004367      1.828709
# min        0.410300      0.947700      0.000000
# 25%        0.581350      0.993700      2.000000
# 50%        0.642000      0.996400      3.000000
# 75%        0.696000      0.997900      5.000000
# max        0.974800      0.999700      6.000000

# %%
from causal_nest.knowledge import parse_knowledge_file

knowledge = parse_knowledge_file('./resources/dry_bean/knowledge.txt')
knowledge
# Out:
# Knowledge(required_edges=[], forbidden_edges=[('ShapeFactor3', 'Class'), ('Solidity', 'Class'), ('ConvexArea', 'Class'), ('Perimeter', 'Class'), ('roundness', 'Class'), ('AspectRation', 'Class'), ('Extent', 'Class'), ('MajorAxisLength', 'Class'), ('EquivDiameter', 'Class'), ('Area', 'Class'), ('ShapeFactor4', 'Class'), ('ShapeFactor2', 'Class'), ('Eccentricity', 'Class'), ('ShapeFactor1', 'Class'), ('Compactness', 'Class'), ('MinorAxisLength', 'Class')])

# %%
from causal_nest.dataset import MissingDataHandlingMethod, Dataset, handle_missing_data, FeatureTypeMap, FeatureType, estimate_feature_importances

feature_mapping = [FeatureTypeMap(feature=c, type=FeatureType.CONTINUOUS) for c in df.drop('Class', axis=1).columns]

dataset = Dataset(data=df, target='Class', feature_mapping=feature_mapping)
dataset = handle_missing_data(dataset, MissingDataHandlingMethod.FORWARD_FILL)
dataset = estimate_feature_importances(dataset)
dataset
# Out:
# Dataset(data=          Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395.0    610.291         208.1781         173.8887        1.1972
# 1      28734.0    638.018         200.5248         182.7344        1.0974
# 2      29380.0    624.110         212.8261         175.9311        1.2097
# 3      30008.0    645.884         210.5580         182.5165        1.1536
# 4      30140.0    620.134         201.8479         190.2793        1.0608
# ...        ...        ...              ...              ...           ...
# 13606  42097.0    759.696         288.7216         185.9447        1.5527
# 13607  42101.0    757.499         281.5764         190.7131        1.4764
# 13608  42139.0    759.321         281.5399         191.1880        1.4726
# 13609  42147.0    763.779         283.3826         190.2757        1.4893
# 13610  42159.0    772.237         295.1427         182.2047        1.6198
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  roundness  \
# 0            0.5498     28715.0       190.1411  0.7639    0.9889     0.9580
# 1            0.4118     29172.0       191.2728  0.7840    0.9850     0.8870
# 2            0.5627     29690.0       193.4109  0.7781    0.9896     0.9478
# 3            0.4986     30724.0       195.4671  0.7827    0.9767     0.9039
# 4            0.3337     30417.0       195.8965  0.7731    0.9909     0.9849
# ...             ...         ...            ...     ...       ...        ...
# 13606        0.7650     42508.0       231.5158  0.7146    0.9903     0.9166
# 13607        0.7357     42494.0       231.5268  0.7999    0.9908     0.9220
# 13608        0.7341     42569.0       231.6313  0.7299    0.9899     0.9184
# 13609        0.7411     42667.0       231.6532  0.7054    0.9878     0.9079
# 13610        0.7867     42600.0       231.6862  0.7890    0.9896     0.8884
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0           0.9134        0.0073        0.0031        0.8342        0.9987
# 1           0.9539        0.0070        0.0036        0.9099        0.9984
# 2           0.9088        0.0072        0.0030        0.8259        0.9991
# 3           0.9283        0.0070        0.0032        0.8618        0.9942
# 4           0.9705        0.0067        0.0037        0.9419        0.9992
# ...            ...           ...           ...           ...           ...
# 13606       0.8019        0.0069        0.0017        0.6430        0.9984
# 13607       0.8223        0.0067        0.0019        0.6761        0.9982
# 13608       0.8227        0.0067        0.0019        0.6769        0.9968
# 13609       0.8175        0.0067        0.0019        0.6682        0.9952
# 13610       0.7850        0.0070        0.0016        0.6162        0.9982
#
#        Class
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
# ...      ...
# 13606    3.0
# 13607    3.0
# 13608    3.0
# 13609    3.0
# 13610    3.0
#
# [13611 rows x 17 columns], target='Class', feature_mapping=[FeatureTypeMap(feature='MinorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.597410618167859), FeatureTypeMap(feature='Perimeter', type=<FeatureType.CONTINUOUS: 3>, importance=0.16176504049087556), FeatureTypeMap(feature='roundness', type=<FeatureType.CONTINUOUS: 3>, importance=0.05084571118579342), FeatureTypeMap(feature='ConvexArea', type=<FeatureType.CONTINUOUS: 3>, importance=0.025646634632922615), FeatureTypeMap(feature='ShapeFactor3', type=<FeatureType.CONTINUOUS: 3>, importance=0.024740032142891666), FeatureTypeMap(feature='Compactness', type=<FeatureType.CONTINUOUS: 3>, importance=0.022912686970232785), FeatureTypeMap(feature='ShapeFactor4', type=<FeatureType.CONTINUOUS: 3>, importance=0.021620055721225027), FeatureTypeMap(feature='ShapeFactor1', type=<FeatureType.CONTINUOUS: 3>, importance=0.018984635290624163), FeatureTypeMap(feature='MajorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.01794997142443045), FeatureTypeMap(feature='Solidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.016618740974130176), FeatureTypeMap(feature='Extent', type=<FeatureType.CONTINUOUS: 3>, importance=0.016188499739428826), FeatureTypeMap(feature='AspectRation', type=<FeatureType.CONTINUOUS: 3>, importance=0.005987803593921138), FeatureTypeMap(feature='Eccentricity', type=<FeatureType.CONTINUOUS: 3>, importance=0.005769862208352244), FeatureTypeMap(feature='EquivDiameter', type=<FeatureType.CONTINUOUS: 3>, importance=0.005167166591614558), FeatureTypeMap(feature='Area', type=<FeatureType.CONTINUOUS: 3>, importance=0.005111732046593017), FeatureTypeMap(feature='ShapeFactor2', type=<FeatureType.CONTINUOUS: 3>, importance=0.003280808819105316)])

# %%
from causal_nest.problem import Problem

problem = Problem(dataset=dataset, description='Dry Bean', knowledge=knowledge)
problem
# Out:
# Problem(dataset=Dataset(data=          Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395.0    610.291         208.1781         173.8887        1.1972
# 1      28734.0    638.018         200.5248         182.7344        1.0974
# 2      29380.0    624.110         212.8261         175.9311        1.2097
# 3      30008.0    645.884         210.5580         182.5165        1.1536
# 4      30140.0    620.134         201.8479         190.2793        1.0608
# ...        ...        ...              ...              ...           ...
# 13606  42097.0    759.696         288.7216         185.9447        1.5527
# 13607  42101.0    757.499         281.5764         190.7131        1.4764
# 13608  42139.0    759.321         281.5399         191.1880        1.4726
# 13609  42147.0    763.779         283.3826         190.2757        1.4893
# 13610  42159.0    772.237         295.1427         182.2047        1.6198
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  roundness  \
# 0            0.5498     28715.0       190.1411  0.7639    0.9889     0.9580
# 1            0.4118     29172.0       191.2728  0.7840    0.9850     0.8870
# 2            0.5627     29690.0       193.4109  0.7781    0.9896     0.9478
# 3            0.4986     30724.0       195.4671  0.7827    0.9767     0.9039
# 4            0.3337     30417.0       195.8965  0.7731    0.9909     0.9849
# ...             ...         ...            ...     ...       ...        ...
# 13606        0.7650     42508.0       231.5158  0.7146    0.9903     0.9166
# 13607        0.7357     42494.0       231.5268  0.7999    0.9908     0.9220
# 13608        0.7341     42569.0       231.6313  0.7299    0.9899     0.9184
# 13609        0.7411     42667.0       231.6532  0.7054    0.9878     0.9079
# 13610        0.7867     42600.0       231.6862  0.7890    0.9896     0.8884
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0           0.9134        0.0073        0.0031        0.8342        0.9987
# 1           0.9539        0.0070        0.0036        0.9099        0.9984
# 2           0.9088        0.0072        0.0030        0.8259        0.9991
# 3           0.9283        0.0070        0.0032        0.8618        0.9942
# 4           0.9705        0.0067        0.0037        0.9419        0.9992
# ...            ...           ...           ...           ...           ...
# 13606       0.8019        0.0069        0.0017        0.6430        0.9984
# 13607       0.8223        0.0067        0.0019        0.6761        0.9982
# 13608       0.8227        0.0067        0.0019        0.6769        0.9968
# 13609       0.8175        0.0067        0.0019        0.6682        0.9952
# 13610       0.7850        0.0070        0.0016        0.6162        0.9982
#
#        Class
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
# ...      ...
# 13606    3.0
# 13607    3.0
# 13608    3.0
# 13609    3.0
# 13610    3.0
#
# [13611 rows x 17 columns], target='Class', feature_mapping=[FeatureTypeMap(feature='MinorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.597410618167859), FeatureTypeMap(feature='Perimeter', type=<FeatureType.CONTINUOUS: 3>, importance=0.16176504049087556), FeatureTypeMap(feature='roundness', type=<FeatureType.CONTINUOUS: 3>, importance=0.05084571118579342), FeatureTypeMap(feature='ConvexArea', type=<FeatureType.CONTINUOUS: 3>, importance=0.025646634632922615), FeatureTypeMap(feature='ShapeFactor3', type=<FeatureType.CONTINUOUS: 3>, importance=0.024740032142891666), FeatureTypeMap(feature='Compactness', type=<FeatureType.CONTINUOUS: 3>, importance=0.022912686970232785), FeatureTypeMap(feature='ShapeFactor4', type=<FeatureType.CONTINUOUS: 3>, importance=0.021620055721225027), FeatureTypeMap(feature='ShapeFactor1', type=<FeatureType.CONTINUOUS: 3>, importance=0.018984635290624163), FeatureTypeMap(feature='MajorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.01794997142443045), FeatureTypeMap(feature='Solidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.016618740974130176), FeatureTypeMap(feature='Extent', type=<FeatureType.CONTINUOUS: 3>, importance=0.016188499739428826), FeatureTypeMap(feature='AspectRation', type=<FeatureType.CONTINUOUS: 3>, importance=0.005987803593921138), FeatureTypeMap(feature='Eccentricity', type=<FeatureType.CONTINUOUS: 3>, importance=0.005769862208352244), FeatureTypeMap(feature='EquivDiameter', type=<FeatureType.CONTINUOUS: 3>, importance=0.005167166591614558), FeatureTypeMap(feature='Area', type=<FeatureType.CONTINUOUS: 3>, importance=0.005111732046593017), FeatureTypeMap(feature='ShapeFactor2', type=<FeatureType.CONTINUOUS: 3>, importance=0.003280808819105316)]), description='Dry Bean', ground_truth=None, knowledge=Knowledge(required_edges=[], forbidden_edges=[('ShapeFactor3', 'Class'), ('Solidity', 'Class'), ('ConvexArea', 'Class'), ('Perimeter', 'Class'), ('roundness', 'Class'), ('AspectRation', 'Class'), ('Extent', 'Class'), ('MajorAxisLength', 'Class'), ('EquivDiameter', 'Class'), ('Area', 'Class'), ('ShapeFactor4', 'Class'), ('ShapeFactor2', 'Class'), ('Eccentricity', 'Class'), ('ShapeFactor1', 'Class'), ('Compactness', 'Class'), ('MinorAxisLength', 'Class')]), discovery_results=None, estimation_results=None, refutation_results=None)

# %% [markdown]
# ## Checking the Feature infered importance

# %%
problem.dataset.feature_mapping
# Out:
# [FeatureTypeMap(feature='MinorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.597410618167859),
#  FeatureTypeMap(feature='Perimeter', type=<FeatureType.CONTINUOUS: 3>, importance=0.16176504049087556),
#  FeatureTypeMap(feature='roundness', type=<FeatureType.CONTINUOUS: 3>, importance=0.05084571118579342),
#  FeatureTypeMap(feature='ConvexArea', type=<FeatureType.CONTINUOUS: 3>, importance=0.025646634632922615),
#  FeatureTypeMap(feature='ShapeFactor3', type=<FeatureType.CONTINUOUS: 3>, importance=0.024740032142891666),
#  FeatureTypeMap(feature='Compactness', type=<FeatureType.CONTINUOUS: 3>, importance=0.022912686970232785),
#  FeatureTypeMap(feature='ShapeFactor4', type=<FeatureType.CONTINUOUS: 3>, importance=0.021620055721225027),
#  FeatureTypeMap(feature='ShapeFactor1', type=<FeatureType.CONTINUOUS: 3>, importance=0.018984635290624163),
#  FeatureTypeMap(feature='MajorAxisLength', type=<FeatureType.CONTINUOUS: 3>, importance=0.01794997142443045),
#  FeatureTypeMap(feature='Solidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.016618740974130176),
#  FeatureTypeMap(feature='Extent', type=<FeatureType.CONTINUOUS: 3>, importance=0.016188499739428826),
#  FeatureTypeMap(feature='AspectRation', type=<FeatureType.CONTINUOUS: 3>, importance=0.005987803593921138),
#  FeatureTypeMap(feature='Eccentricity', type=<FeatureType.CONTINUOUS: 3>, importance=0.005769862208352244),
#  FeatureTypeMap(feature='EquivDiameter', type=<FeatureType.CONTINUOUS: 3>, importance=0.005167166591614558),
#  FeatureTypeMap(feature='Area', type=<FeatureType.CONTINUOUS: 3>, importance=0.005111732046593017),
#  FeatureTypeMap(feature='ShapeFactor2', type=<FeatureType.CONTINUOUS: 3>, importance=0.003280808819105316)]

# %% [markdown]
# # Causal Discovery

# %%
from causal_nest.discovery import applyable_models

models = applyable_models(problem)
models
# Out:
# [causal_nest.discovery_models.pc.PC,
#  causal_nest.discovery_models.gs.GS,
#  causal_nest.discovery_models.ccdr.CCDR,
#  causal_nest.discovery_models.iamb.IAMB,
#  causal_nest.discovery_models.sam.SAM,
#  causal_nest.discovery_models.bes.BES,
#  causal_nest.discovery_models.grasp.GRASP,
#  causal_nest.discovery_models.cgnn.CGNN]

# %%
from causal_nest.discovery import discover_with_all_models

problem = discover_with_all_models(problem, verbose=True, max_seconds_model=14500)
problem.discovery_results
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# GRaSP edge count: 101
# ~Stats for CCDR~
#
# 		Runtime: 26.720195 seconds
# 		AUC_PR: None
# 		SHD: None
# 		SID: None
# 		Priority Score: 1.144921636474659
# 		Integrity Score: 0.5
# 		Forbidden Edges Violation Rate: 0.5		Required Edges Compliance Rate: 1.0
# GRaSP edge count: 100
# ~Stats for PC~
#
# 		Runtime: 31.728541 seconds
# 		AUC_PR: None
# 		SHD: None
# 		SID: None
# 		Priority Score: 0.0
# 		Integrity Score: 1.0
# 		Forbidden Edges Violation Rate: 0.0
# 		Required Edges Compliance Rate: 1.0
#
#
# GRaSP edge count: 99
#   0%|          | 0/1000 [00:42<?, ?it/s, disc=0.315, gen=-.136, regul_loss=0.197, tot=-7.17]
# GRaSP edge count: 109
#   0%|          | 1/1000 [01:02<17:15:22, 62.18s/it, disc=0.315, gen=-.136, regul_loss=0.197, tot=-7.17]
# GRaSP edge count: 100
#   0%|          | 2/1000 [02:00<16:32:14, 59.65s/it, disc=0.315, gen=-.136, regul_loss=0.197, tot=-7.17]
# GRaSP edge count: 97
# GRaSP completed in: 158.38s
#   0%|          | 3/1000 [02:50<15:22:38, 55.53s/it, disc=0.315, gen=-.136, regul_loss=0.197, tot=-7.17]

# %%
list(sorted(filter(lambda x: x, problem.discovery_results.values()), key=lambda x: x.priority_score, reverse=True))

# %% [markdown]
# # Causal Estimation

# %%
from causal_nest.estimation import estimate_all_effects

problem = estimate_all_effects(problem, verbose=True)
problem.estimation_results

# %%
for m, er in problem.estimation_results.items():
    print('\n\n\nModel: ', m)
    for r in er:
        print(r.treatment, ': ', r.estimate.value)

# %% [markdown]
# # Refutation

# %%
from causal_nest.refutation import refute_all_results

problem = refute_all_results(problem, max_seconds_global=3600, max_seconds_model=500)
problem.refutation_results

# %% [markdown]
# # Output Graphs

# %%
from causal_nest.result import generate_all_results


graphs = generate_all_results(problem)
graphs

# %%
from graphviz import Source

for k, v in graphs.items():
    print(k)

    if v is None: 
        print('No graph')
    else:
        display(Source(v))

# %%
from causal_nest.stats import calculate_auc_pr, calculate_shd, calculate_sid
from itertools import combinations

for t1, t2 in list(combinations(problem.discovery_results.keys(), 2)):
    if problem.discovery_results[t1] is None or problem.discovery_results[t2] is None:
        print(f"{t1} / {t2}: - - -")
        continue
        
    g1 = problem.discovery_results[t1].output_graph
    g2 = problem.discovery_results[t2].output_graph
    
    auc_pr = calculate_auc_pr(g1, g2)
    shd = calculate_shd(g1, g2)
    sid = calculate_sid(g1, g2)
    
    print(f"{t1} / {t2}: {auc_pr:.2f} {shd:.2f} {sid:.2f}")

# %%
for k, v in problem.discovery_results.items():
    print(f'\tModel: {k}')
    
    if (v is None):
        print(f'Null results')
        print('\t----------\n')
        continue

    mce_treatment = mce = mce_p = None
    sr = sorted(filter(lambda x: x.estimate.value and x.p_value is not None and x.p_value[0] >= 0, problem.estimation_results[k]), key=lambda x: x.estimate.value, reverse=True)
    if (len(sr) > 0):
        mce = sr[0].estimate.value
        mce_p = sr[0].p_value[0] if sr[0].p_value is not None else -666
        mce_treatment = sr[0].treatment

    ref_rate = 0
    if (mce_treatment is not None):
        refs = list(filter(lambda x: x.treatment == mce_treatment, problem.refutation_results[k]))
        if (len(refs) > 0):
            ref_rate = len(list(filter(lambda x: x.passed == True, refs))) / len(refs)
    
    print(f'FER: {100 * v.forbidden_edges_violation_rate:.2f}')
    print(f'RECR: {100 * v.required_edges_compliance_rate:.2f}')
    print(f'IS: {v.knowledge_integrity_score:.2f}')
    if mce is not None:
        print(f'MCE: {mce:.2f}')
        print(f'MCE P-Value: {mce_p:.2E}')
        print(f'MCE Refutation Rate: {100 * ref_rate:.2f}')
    print('\t----------\n')
